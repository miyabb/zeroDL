# %%
import numpy as np

class TwoLayerNet:

    def __init__(self,input_size,hidden_size,output_size,weight_init_std=0.01):
        #重みの初期化
        self.params = {}
        #784 * 50の重み行列
        self.params['W1'] = weight_init_std * np.random.randn(input_size,hidden_size)
        #50 * 10の重み行列
        self.params['W2'] = weight_init_std * np.random.randn(hidden_size,output_size)
        #バイアス，隠れ層の数だけ
        self.params['b1'] = np.zeros(hidden_size)
        #バイアス，出力層の数だけ
        self.params['b2'] = np.zeros(output_size)
    
    # 隠れ層のユニット 一つの値を[0,1]に落とし込む
    def sigmoid(self,x):
        return 1 / (1 + np.exp(-x))
    
    # 出力層のユニット 複数の値の組合せからそれぞれの値を合計1の形に落とし込む
    def softmax(self,a):
        c = np.max(a)
        exp_a = np.exp(a - c)#オーバーフロー対策
        sum_exp_a = np.sum(exp_a)
        y = exp_a / sum_exp_a
        return y
    
    # 勾配計算(1次元) 損失関数の勾配を取る 中心差分
    def _numerical_gradient_1d(self,f, x):
        h = 1e-4 # 0.0001
        grad = np.zeros_like(x)

        for idx in range(x.size):
            tmp_val = x[idx]
            x[idx] = float(tmp_val) + h
            fxh1 = f(x) # f(x+h)

            x[idx] = tmp_val - h 
            fxh2 = f(x) # f(x-h)
            grad[idx] = (fxh1 - fxh2) / (2*h)

            x[idx] = tmp_val # 値を元に戻す

        return grad

    # 勾配計算
    def numerical_gradient(self,f, X):
        if X.ndim == 1:
            return self._numerical_gradient_1d(f, X)
        else:
            # Xと同じ形の0行列を生成
            grad = np.zeros_like(X)
            
            for idx, x in enumerate(X):
                grad[idx] = self._numerical_gradient_1d(f, x)

            return grad
        
    # 損失関数 交差エントロピー誤差
    # 正解ラベルの場合，その確信度yが高いほど小さくなる 0で高い場合どうする?
    def cross_entropy_error(self,y,t):
        if y.ndim == 1:
            t = t.reshape(1,t.size)
            y = y.reshape(1,y.size)
        batch_size = y.shape[0]
        return -np.sum(t * np.log(y)) / batch_size
    
    def predict(self,x):
        W1,W2 = self.params['W1'],self.params['W2']
        b1,b2 = self.params['b1'],self.params['b2']

        a1 = np.dot(x,W1) + b1 #a1 = Wx1 + b1
        z1 = self.sigmoid(a1)  #x2 = h(a)
        a2 = np.dot(z1,W2) + b2#a2 = Wx2 + b2
        z2 = self.softmax(a2)  #各クラスの確率値に変換

        return z2

    def loss(self, x, t):
        y = self.predict(x)

        return self.cross_entropy_error(y,t)

    def accuracy(self, x, t):
        y = self.predict(x)
        y = np.argmax(y,axis=1)
        t = np.argmax(t,axis=1)

        accuracy = np.sum(y == t) / float(x.shape[0])
        return accuracy
    
    # 勾配計算
    def gradient(self,x,t):
        loss_W = lambda W: self.loss(x,t)
        grads = {}
        grads['W1'] = self.numerical_gradient(loss_W,self.params['W1'])
        grads['W2'] = self.numerical_gradient(loss_W,self.params['W2'])
        grads['b1'] = self.numerical_gradient(loss_W,self.params['b1'])
        grads['b2'] = self.numerical_gradient(loss_W,self.params['b2'])

        return grads

# %%
#coding: utf-8
import numpy as np
from sklearn.datasets import fetch_mldata
from sklearn.preprocessing import OneHotEncoder
from tqdm import tqdm

# MNISTのダウンロード
mnist = fetch_mldata('MNIST original', data_home=".")

# 訓練データ
x_train = mnist['data'][:60000]
t_train = mnist['target'][:60000]

# trainと同じ形にする -1は自動的に調整
# 無駄な処理
t_train = t_train.reshape(1, -1).transpose()

# encode label
# labelごとのone-hot表現として取り扱う
encoder = OneHotEncoder(n_values=max(t_train)+1)
t_train = encoder.fit_transform(t_train).toarray()

# テストデータ
x_test = mnist['data'][60000:]
t_test = mnist['target'][60000:]

t_test = t_test.reshape(1, -1).transpose()

# encode label
# transformする必要
t_test = encoder.transform(t_test).toarray()

# 学習データがint型なのでfloatに変換，その後[0,1]に正規化する，max = 255
x_train  = x_train.astype(np.float64)
x_train /= x_train.max()
x_test   = x_test.astype(np.float64)
x_test  /= x_test.max()

train_loss_list = []
train_acc_list  = []
test_acc_list   = []

#hyper parameter
iters_num = 1000
train_size = x_train.shape[0]
batch_size = 100
learning_rate = 0.1

# 1エポックあたりの繰り返し数
#iter_per_epoch = max(train_size / batch_size, 1)
iter_per_epoch = 1

network = TwoLayerNet(input_size=784,hidden_size=50,output_size=10)

for i in range(iters_num):
    
    # train_sizeの中からbatch_size分ミニバッチのサンプルをとる
    batch_mask = np.random.choice(train_size,batch_size)
    x_batch = x_train[batch_mask]
    t_batch = t_train[batch_mask]
    
    # 勾配を計算する
    grad = network.gradient(x_batch,t_batch)
    
    # ミニバッチによってparameterの更新 x - eta * grad
    for key in ('W1','W2','b1','b2'):
        network.params[key] -= learning_rate * grad[key]
    
    # 全体のlossを格納
    loss = network.loss(x_batch,t_batch)
    train_loss_list.append(loss)
    
    # 1エポックごとに認識精度を計算
    #if i % iter_per_epoch == 0:
    
    # acc
    train_acc = network.accuracy(x_train, t_train)
    test_acc = network.accuracy(x_test, t_test)
    
    # accの格納
    train_acc_list.append(train_acc)
    test_acc_list.append(test_acc)
    print("train acc, test acc | " + str(train_acc) + ", " + str(test_acc))
# Out:
# train acc, test acc | 0.0983166666667, 0.0955
# train acc, test acc | 0.0973666666667, 0.0982
# train acc, test acc | 0.0973666666667, 0.0982
# train acc, test acc | 0.0973666666667, 0.0982
# train acc, test acc | 0.0986333333333, 0.0958
# train acc, test acc | 0.0973666666667, 0.0981
# train acc, test acc | 0.09915, 0.1009
# train acc, test acc | 0.09915, 0.1009
# train acc, test acc | 0.09915, 0.1009
# train acc, test acc | 0.09915, 0.1009
# train acc, test acc | 0.09915, 0.1009
# train acc, test acc | 0.112366666667, 0.1135
# train acc, test acc | 0.102183333333, 0.101
# train acc, test acc | 0.102183333333, 0.101
# train acc, test acc | 0.112366666667, 0.1135
# train acc, test acc | 0.112366666667, 0.1135
# train acc, test acc | 0.112366666667, 0.1135
# train acc, test acc | 0.112366666667, 0.1135
# train acc, test acc | 0.112366666667, 0.1135
# train acc, test acc | 0.112366666667, 0.1135
# train acc, test acc | 0.112366666667, 0.1135
# train acc, test acc | 0.112366666667, 0.1135
# train acc, test acc | 0.112366666667, 0.1135
# train acc, test acc | 0.112366666667, 0.1135
# train acc, test acc | 0.112366666667, 0.1135
# train acc, test acc | 0.112366666667, 0.1135
# train acc, test acc | 0.112366666667, 0.1135
# train acc, test acc | 0.112366666667, 0.1135
# train acc, test acc | 0.112366666667, 0.1135
# train acc, test acc | 0.112366666667, 0.1135
# train acc, test acc | 0.112366666667, 0.1135
# train acc, test acc | 0.112366666667, 0.1135
# train acc, test acc | 0.112366666667, 0.1135
# train acc, test acc | 0.112366666667, 0.1135
# train acc, test acc | 0.112366666667, 0.1135
# train acc, test acc | 0.112366666667, 0.1135
# train acc, test acc | 0.112366666667, 0.1135
# train acc, test acc | 0.112366666667, 0.1135
# train acc, test acc | 0.112366666667, 0.1135
# train acc, test acc | 0.112366666667, 0.1135
# train acc, test acc | 0.112366666667, 0.1135
# train acc, test acc | 0.0996, 0.1012
# train acc, test acc | 0.185, 0.1928
# train acc, test acc | 0.129933333333, 0.1342
# train acc, test acc | 0.09915, 0.1009
# train acc, test acc | 0.09915, 0.1009
# train acc, test acc | 0.09915, 0.1009
# train acc, test acc | 0.10325, 0.1003
# train acc, test acc | 0.0973666666667, 0.0982
# train acc, test acc | 0.09915, 0.1009
# train acc, test acc | 0.18655, 0.184
# train acc, test acc | 0.09915, 0.1009
# train acc, test acc | 0.0973666666667, 0.0982
# train acc, test acc | 0.0973666666667, 0.0982
# train acc, test acc | 0.137166666667, 0.1334
# train acc, test acc | 0.112366666667, 0.1135
# train acc, test acc | 0.112366666667, 0.1135
# train acc, test acc | 0.112366666667, 0.1135
# train acc, test acc | 0.112366666667, 0.1135
# train acc, test acc | 0.112366666667, 0.1135
# train acc, test acc | 0.112366666667, 0.1135
# train acc, test acc | 0.112366666667, 0.1135
# train acc, test acc | 0.112366666667, 0.1135
# train acc, test acc | 0.159533333333, 0.1592
# train acc, test acc | 0.112366666667, 0.1135
# train acc, test acc | 0.112366666667, 0.1135
# train acc, test acc | 0.198316666667, 0.2013
# train acc, test acc | 0.141966666667, 0.1485
# train acc, test acc | 0.112366666667, 0.1135
# train acc, test acc | 0.202466666667, 0.2055
# train acc, test acc | 0.112366666667, 0.1135
# train acc, test acc | 0.112366666667, 0.1135
# train acc, test acc | 0.112366666667, 0.1135
# train acc, test acc | 0.112366666667, 0.1135
# train acc, test acc | 0.102183333333, 0.101
# train acc, test acc | 0.102183333333, 0.101
# train acc, test acc | 0.102183333333, 0.101
# train acc, test acc | 0.0973666666667, 0.0982
# train acc, test acc | 0.100883333333, 0.1018
# train acc, test acc | 0.146716666667, 0.1467
# train acc, test acc | 0.0987333333333, 0.0995
# train acc, test acc | 0.0973666666667, 0.0982
# train acc, test acc | 0.12315, 0.1232
# train acc, test acc | 0.201816666667, 0.2048
# train acc, test acc | 0.364016666667, 0.3606
# train acc, test acc | 0.275966666667, 0.2751
# train acc, test acc | 0.162483333333, 0.16
# train acc, test acc | 0.207783333333, 0.2067
# train acc, test acc | 0.206133333333, 0.205
# train acc, test acc | 0.165133333333, 0.1618
# train acc, test acc | 0.230016666667, 0.2273
# train acc, test acc | 0.186433333333, 0.1836
# train acc, test acc | 0.287733333333, 0.281
# train acc, test acc | 0.183533333333, 0.1812
# train acc, test acc | 0.157866666667, 0.1557
# train acc, test acc | 0.19585, 0.1948
# train acc, test acc | 0.21965, 0.2216
# train acc, test acc | 0.208766666667, 0.2102
# train acc, test acc | 0.2098, 0.2109
# train acc, test acc | 0.0987166666667, 0.098
# train acc, test acc | 0.165716666667, 0.1708
# train acc, test acc | 0.126533333333, 0.1294
# train acc, test acc | 0.219416666667, 0.2203
# train acc, test acc | 0.143, 0.1437
# train acc, test acc | 0.2823, 0.2817
# train acc, test acc | 0.2098, 0.2109
# train acc, test acc | 0.204383333333, 0.2058
# train acc, test acc | 0.242333333333, 0.2424
# train acc, test acc | 0.170616666667, 0.1698
# train acc, test acc | 0.303216666667, 0.3019
# train acc, test acc | 0.256, 0.2612
# train acc, test acc | 0.129033333333, 0.1281
# train acc, test acc | 0.14835, 0.15
# train acc, test acc | 0.112366666667, 0.1135
# train acc, test acc | 0.112366666667, 0.1135
# train acc, test acc | 0.143133333333, 0.1445
# train acc, test acc | 0.1471, 0.1433
# train acc, test acc | 0.210383333333, 0.2085
# train acc, test acc | 0.104416666667, 0.1028
# train acc, test acc | 0.134616666667, 0.1368
# train acc, test acc | 0.114116666667, 0.1157
# train acc, test acc | 0.112366666667, 0.1135
# train acc, test acc | 0.112366666667, 0.1135
# train acc, test acc | 0.112366666667, 0.1135
# train acc, test acc | 0.114183333333, 0.1162
# train acc, test acc | 0.112366666667, 0.1135
# train acc, test acc | 0.232, 0.2302
# train acc, test acc | 0.117783333333, 0.1207
# train acc, test acc | 0.214133333333, 0.2141
# train acc, test acc | 0.146483333333, 0.1476
# train acc, test acc | 0.199766666667, 0.2001
# train acc, test acc | 0.197866666667, 0.1972
# train acc, test acc | 0.2101, 0.2086
# train acc, test acc | 0.210483333333, 0.2097
# train acc, test acc | 0.142666666667, 0.1438
# train acc, test acc | 0.112366666667, 0.1135
# train acc, test acc | 0.112366666667, 0.1135
# train acc, test acc | 0.112366666667, 0.1135
# train acc, test acc | 0.114433333333, 0.1161
# train acc, test acc | 0.156816666667, 0.1683
# train acc, test acc | 0.267616666667, 0.2736
# train acc, test acc | 0.18115, 0.1865
# train acc, test acc | 0.199783333333, 0.2009
# train acc, test acc | 0.1694, 0.174
# train acc, test acc | 0.193733333333, 0.1994
# train acc, test acc | 0.117033333333, 0.1192
# train acc, test acc | 0.15635, 0.1565
# train acc, test acc | 0.153233333333, 0.1541
# train acc, test acc | 0.148066666667, 0.1485
# train acc, test acc | 0.181033333333, 0.1791
# train acc, test acc | 0.18655, 0.1838
# train acc, test acc | 0.312133333333, 0.3144
# train acc, test acc | 0.344133333333, 0.3383
# train acc, test acc | 0.2791, 0.2873
# train acc, test acc | 0.107416666667, 0.1129
# train acc, test acc | 0.16145, 0.1716
# train acc, test acc | 0.161333333333, 0.1713
# train acc, test acc | 0.1024, 0.1062
# train acc, test acc | 0.121616666667, 0.1261
# train acc, test acc | 0.100916666667, 0.1053
# train acc, test acc | 0.127866666667, 0.1383
# train acc, test acc | 0.24865, 0.2507
# train acc, test acc | 0.292233333333, 0.3041
# train acc, test acc | 0.202333333333, 0.2112
# train acc, test acc | 0.26605, 0.2675
# train acc, test acc | 0.358266666667, 0.3695
# train acc, test acc | 0.454933333333, 0.4647
# train acc, test acc | 0.178933333333, 0.1796
# train acc, test acc | 0.169633333333, 0.1701
# train acc, test acc | 0.174683333333, 0.1755
# train acc, test acc | 0.1506, 0.1518
# train acc, test acc | 0.194633333333, 0.1955
# train acc, test acc | 0.217316666667, 0.2144
# train acc, test acc | 0.32625, 0.3313
# train acc, test acc | 0.316683333333, 0.3216
# train acc, test acc | 0.307366666667, 0.3117
# train acc, test acc | 0.385716666667, 0.3867
# train acc, test acc | 0.3011, 0.3035
# train acc, test acc | 0.247383333333, 0.2501
# train acc, test acc | 0.270183333333, 0.2768
# train acc, test acc | 0.276483333333, 0.2873
# train acc, test acc | 0.238866666667, 0.247
# train acc, test acc | 0.337666666667, 0.3437
# train acc, test acc | 0.368383333333, 0.3722
# train acc, test acc | 0.288883333333, 0.291
# train acc, test acc | 0.299, 0.2978
# train acc, test acc | 0.284116666667, 0.2845
# train acc, test acc | 0.337983333333, 0.3398
# train acc, test acc | 0.365183333333, 0.3673
# train acc, test acc | 0.343466666667, 0.3436
# train acc, test acc | 0.308716666667, 0.3083
# train acc, test acc | 0.291283333333, 0.2907
# train acc, test acc | 0.287266666667, 0.2883
# train acc, test acc | 0.307633333333, 0.3085
# train acc, test acc | 0.346383333333, 0.3478
# train acc, test acc | 0.321366666667, 0.3187
# train acc, test acc | 0.33235, 0.3317
# train acc, test acc | 0.348633333333, 0.3488
# train acc, test acc | 0.387616666667, 0.3913
# train acc, test acc | 0.353216666667, 0.357
# train acc, test acc | 0.342566666667, 0.3509
# train acc, test acc | 0.3508, 0.3562
# train acc, test acc | 0.390633333333, 0.3948
# train acc, test acc | 0.328416666667, 0.3258
# train acc, test acc | 0.339933333333, 0.3381
# train acc, test acc | 0.34565, 0.349
# train acc, test acc | 0.337233333333, 0.3421
# train acc, test acc | 0.308333333333, 0.313
# train acc, test acc | 0.302133333333, 0.3062
# train acc, test acc | 0.28285, 0.2863
# train acc, test acc | 0.359483333333, 0.3617
# train acc, test acc | 0.304466666667, 0.3036
# train acc, test acc | 0.304033333333, 0.2991
# train acc, test acc | 0.332433333333, 0.3299
# train acc, test acc | 0.31755, 0.314
# train acc, test acc | 0.329733333333, 0.3269
# train acc, test acc | 0.368916666667, 0.3673
# train acc, test acc | 0.366533333333, 0.3717
# train acc, test acc | 0.314633333333, 0.3171
# train acc, test acc | 0.290483333333, 0.289
# train acc, test acc | 0.359516666667, 0.3586
# train acc, test acc | 0.377033333333, 0.3801
# train acc, test acc | 0.372316666667, 0.3716
# train acc, test acc | 0.445016666667, 0.4496
# train acc, test acc | 0.44985, 0.4495
# train acc, test acc | 0.452816666667, 0.46
# train acc, test acc | 0.42335, 0.4234
# train acc, test acc | 0.448766666667, 0.4527
# train acc, test acc | 0.482016666667, 0.4876
# train acc, test acc | 0.424583333333, 0.4197
# train acc, test acc | 0.408066666667, 0.4034
# train acc, test acc | 0.393633333333, 0.3885
# train acc, test acc | 0.435266666667, 0.4328
# train acc, test acc | 0.480866666667, 0.4817
# train acc, test acc | 0.493166666667, 0.4952
# train acc, test acc | 0.46515, 0.4661
# train acc, test acc | 0.540066666667, 0.5377
# train acc, test acc | 0.5224, 0.5302
# train acc, test acc | 0.4869, 0.4867
# train acc, test acc | 0.502816666667, 0.5044
# train acc, test acc | 0.55495, 0.5647
# train acc, test acc | 0.477783333333, 0.4798
# train acc, test acc | 0.4701, 0.4741
# train acc, test acc | 0.445166666667, 0.4492
# train acc, test acc | 0.420316666667, 0.4237
# train acc, test acc | 0.449583333333, 0.4571
# train acc, test acc | 0.38775, 0.3936
# train acc, test acc | 0.358633333333, 0.3651
# train acc, test acc | 0.460233333333, 0.4658
# train acc, test acc | 0.482516666667, 0.4921
# train acc, test acc | 0.512083333333, 0.5245
# train acc, test acc | 0.452333333333, 0.4619
# train acc, test acc | 0.480566666667, 0.4835
# train acc, test acc | 0.490783333333, 0.4929
# train acc, test acc | 0.53035, 0.5379
# train acc, test acc | 0.5017, 0.5055
# train acc, test acc | 0.506533333333, 0.5103
# train acc, test acc | 0.489366666667, 0.4943
# train acc, test acc | 0.535966666667, 0.5406
# train acc, test acc | 0.506333333333, 0.5085
# train acc, test acc | 0.4714, 0.4711
# train acc, test acc | 0.516583333333, 0.5166
# train acc, test acc | 0.485766666667, 0.4883
# train acc, test acc | 0.493683333333, 0.4949
# train acc, test acc | 0.460283333333, 0.4584
# train acc, test acc | 0.486066666667, 0.4899
# train acc, test acc | 0.51605, 0.5227
# train acc, test acc | 0.533383333333, 0.5386
# train acc, test acc | 0.5071, 0.5131
# train acc, test acc | 0.49695, 0.503
# train acc, test acc | 0.503316666667, 0.507
# train acc, test acc | 0.51835, 0.5227
# train acc, test acc | 0.5376, 0.5437
# train acc, test acc | 0.521016666667, 0.5278
# train acc, test acc | 0.531966666667, 0.5383
# train acc, test acc | 0.53195, 0.5419
# train acc, test acc | 0.54585, 0.5545
# train acc, test acc | 0.545833333333, 0.5517
# train acc, test acc | 0.559816666667, 0.563
# train acc, test acc | 0.5451, 0.5482
# train acc, test acc | 0.5137, 0.5113
# train acc, test acc | 0.517616666667, 0.5206
# train acc, test acc | 0.53085, 0.5355
# train acc, test acc | 0.534916666667, 0.5377
# train acc, test acc | 0.5427, 0.5447
# train acc, test acc | 0.543083333333, 0.5449
# train acc, test acc | 0.545483333333, 0.5501
# train acc, test acc | 0.518766666667, 0.5256
# train acc, test acc | 0.520866666667, 0.5243
# train acc, test acc | 0.5423, 0.5468
# train acc, test acc | 0.52305, 0.5271
# train acc, test acc | 0.532133333333, 0.5344
# train acc, test acc | 0.518033333333, 0.5246
# train acc, test acc | 0.510916666667, 0.5173
# train acc, test acc | 0.49585, 0.5006
# train acc, test acc | 0.551933333333, 0.5578
# train acc, test acc | 0.5248, 0.5246
# train acc, test acc | 0.529116666667, 0.5259
# train acc, test acc | 0.536766666667, 0.5394
# train acc, test acc | 0.534316666667, 0.5347
# train acc, test acc | 0.53525, 0.5341
# train acc, test acc | 0.497733333333, 0.4941
# train acc, test acc | 0.522233333333, 0.5203
# train acc, test acc | 0.538766666667, 0.5381
# train acc, test acc | 0.546616666667, 0.5508
# train acc, test acc | 0.559816666667, 0.5626
# train acc, test acc | 0.555333333333, 0.559
# train acc, test acc | 0.563433333333, 0.5655
# train acc, test acc | 0.578533333333, 0.5842
# train acc, test acc | 0.57255, 0.5755
# train acc, test acc | 0.596733333333, 0.6017
# train acc, test acc | 0.6077, 0.6169
# train acc, test acc | 0.61875, 0.6268
# train acc, test acc | 0.62845, 0.6361
# train acc, test acc | 0.61895, 0.6289
# train acc, test acc | 0.5963, 0.6017
# train acc, test acc | 0.57255, 0.5768
# train acc, test acc | 0.580466666667, 0.5849
# train acc, test acc | 0.580433333333, 0.5833
# train acc, test acc | 0.583666666667, 0.5859
# train acc, test acc | 0.581533333333, 0.585
# train acc, test acc | 0.592866666667, 0.598
# train acc, test acc | 0.597166666667, 0.6021
# train acc, test acc | 0.586166666667, 0.5902
# train acc, test acc | 0.552416666667, 0.5557
# train acc, test acc | 0.5515, 0.552
# train acc, test acc | 0.543, 0.5482
# train acc, test acc | 0.555683333333, 0.5578
# train acc, test acc | 0.558366666667, 0.5624
# train acc, test acc | 0.552533333333, 0.5555
# train acc, test acc | 0.5523, 0.5548
# train acc, test acc | 0.565383333333, 0.5724
# train acc, test acc | 0.572016666667, 0.5764
# train acc, test acc | 0.567483333333, 0.5733
# train acc, test acc | 0.581516666667, 0.5886
# train acc, test acc | 0.581233333333, 0.5871
# train acc, test acc | 0.605316666667, 0.6152
# train acc, test acc | 0.606883333333, 0.612
# train acc, test acc | 0.596066666667, 0.6016
# train acc, test acc | 0.598683333333, 0.6043
# train acc, test acc | 0.5813, 0.5841
# train acc, test acc | 0.564166666667, 0.5672
# train acc, test acc | 0.6018, 0.6074
# train acc, test acc | 0.615583333333, 0.6226
# train acc, test acc | 0.626583333333, 0.6321
# train acc, test acc | 0.615616666667, 0.6168
# train acc, test acc | 0.619783333333, 0.6232
# train acc, test acc | 0.61945, 0.6226
# train acc, test acc | 0.6144, 0.6191
# train acc, test acc | 0.6196, 0.6257
# train acc, test acc | 0.624583333333, 0.6314
# train acc, test acc | 0.625916666667, 0.6302
# train acc, test acc | 0.622783333333, 0.6271
# train acc, test acc | 0.624033333333, 0.6282
# train acc, test acc | 0.62585, 0.6296
# train acc, test acc | 0.639916666667, 0.6455
# train acc, test acc | 0.61665, 0.6213
# train acc, test acc | 0.61635, 0.6205
# train acc, test acc | 0.61445, 0.6198
# train acc, test acc | 0.63365, 0.6375
# train acc, test acc | 0.63275, 0.6389
# train acc, test acc | 0.65065, 0.6561
# train acc, test acc | 0.633416666667, 0.6408
# train acc, test acc | 0.635916666667, 0.642
# train acc, test acc | 0.635533333333, 0.6394
# train acc, test acc | 0.653083333333, 0.658
# train acc, test acc | 0.655333333333, 0.6621
# train acc, test acc | 0.652116666667, 0.6567
# train acc, test acc | 0.655166666667, 0.6626
# train acc, test acc | 0.65165, 0.661
# train acc, test acc | 0.6367, 0.6446
# train acc, test acc | 0.63145, 0.6362
# train acc, test acc | 0.639816666667, 0.6469
# train acc, test acc | 0.658483333333, 0.6673
# train acc, test acc | 0.660566666667, 0.666
# train acc, test acc | 0.63505, 0.6436
# train acc, test acc | 0.639083333333, 0.6445
# train acc, test acc | 0.654033333333, 0.6645
# train acc, test acc | 0.6406, 0.6491
# train acc, test acc | 0.647066666667, 0.6572
# train acc, test acc | 0.641416666667, 0.6492
# train acc, test acc | 0.641233333333, 0.6489
# train acc, test acc | 0.643766666667, 0.6544
# train acc, test acc | 0.654516666667, 0.6624
# train acc, test acc | 0.6462, 0.6537
# train acc, test acc | 0.6517, 0.659
# train acc, test acc | 0.669416666667, 0.6769
# train acc, test acc | 0.6695, 0.6771
# train acc, test acc | 0.668116666667, 0.6783
# train acc, test acc | 0.674283333333, 0.6796
# train acc, test acc | 0.6652, 0.6717
# train acc, test acc | 0.689433333333, 0.696
# train acc, test acc | 0.684033333333, 0.69
# train acc, test acc | 0.6803, 0.6867
# train acc, test acc | 0.69475, 0.7012
# train acc, test acc | 0.6884, 0.6954
# train acc, test acc | 0.7069, 0.7124
# train acc, test acc | 0.714383333333, 0.7186
# train acc, test acc | 0.707083333333, 0.7132
# train acc, test acc | 0.71465, 0.7223
# train acc, test acc | 0.702083333333, 0.7082
# train acc, test acc | 0.706633333333, 0.7109
# train acc, test acc | 0.7053, 0.712
# train acc, test acc | 0.699616666667, 0.7071
# train acc, test acc | 0.692183333333, 0.6976
# train acc, test acc | 0.686633333333, 0.6902
# train acc, test acc | 0.681116666667, 0.6856
# train acc, test acc | 0.6806, 0.6863
# train acc, test acc | 0.682116666667, 0.6909
# train acc, test acc | 0.70055, 0.7076
# train acc, test acc | 0.685783333333, 0.6946
# train acc, test acc | 0.701883333333, 0.7096
# train acc, test acc | 0.706883333333, 0.7098
# train acc, test acc | 0.70565, 0.7112
# train acc, test acc | 0.6836, 0.6925
# train acc, test acc | 0.71515, 0.7223
# train acc, test acc | 0.724833333333, 0.7268
# train acc, test acc | 0.71165, 0.7191
# train acc, test acc | 0.7266, 0.7328
# train acc, test acc | 0.728416666667, 0.7359
# train acc, test acc | 0.723866666667, 0.7311
# train acc, test acc | 0.714166666667, 0.7206
# train acc, test acc | 0.709583333333, 0.7166
# train acc, test acc | 0.685483333333, 0.6929
# train acc, test acc | 0.690133333333, 0.6965
# train acc, test acc | 0.675383333333, 0.6827
# train acc, test acc | 0.691983333333, 0.6945
# train acc, test acc | 0.696966666667, 0.7005
# train acc, test acc | 0.679316666667, 0.6867
# train acc, test acc | 0.66715, 0.6747
# train acc, test acc | 0.675833333333, 0.6817
# train acc, test acc | 0.706666666667, 0.709
# train acc, test acc | 0.688983333333, 0.6961
# train acc, test acc | 0.691933333333, 0.6961
# train acc, test acc | 0.68405, 0.6891
# train acc, test acc | 0.684483333333, 0.6888
# train acc, test acc | 0.685733333333, 0.6903
# train acc, test acc | 0.699366666667, 0.7011
# train acc, test acc | 0.696916666667, 0.6992
# train acc, test acc | 0.694066666667, 0.6994
# train acc, test acc | 0.6987, 0.7014
# train acc, test acc | 0.713966666667, 0.7137
# train acc, test acc | 0.72115, 0.7237
# train acc, test acc | 0.7144, 0.7196
# train acc, test acc | 0.72945, 0.733
# train acc, test acc | 0.73255, 0.7346
# train acc, test acc | 0.735083333333, 0.74
# train acc, test acc | 0.741383333333, 0.7468
# train acc, test acc | 0.738866666667, 0.7424
# train acc, test acc | 0.744033333333, 0.7477
# train acc, test acc | 0.726966666667, 0.7327
# train acc, test acc | 0.712083333333, 0.7159
# train acc, test acc | 0.723916666667, 0.7293
# train acc, test acc | 0.72045, 0.725
# train acc, test acc | 0.705416666667, 0.7112
# train acc, test acc | 0.715566666667, 0.7212
# train acc, test acc | 0.717133333333, 0.7234
# train acc, test acc | 0.734633333333, 0.7372
# train acc, test acc | 0.7277, 0.7339
# train acc, test acc | 0.7066, 0.7146
# train acc, test acc | 0.707266666667, 0.7169
# train acc, test acc | 0.707216666667, 0.7154
# train acc, test acc | 0.7108, 0.7196
# train acc, test acc | 0.72225, 0.7309
# train acc, test acc | 0.722633333333, 0.7311
# train acc, test acc | 0.720266666667, 0.7278
# train acc, test acc | 0.736766666667, 0.7447
# train acc, test acc | 0.74175, 0.7487
# train acc, test acc | 0.732333333333, 0.7407
# train acc, test acc | 0.73525, 0.7431
# train acc, test acc | 0.712633333333, 0.7181
# train acc, test acc | 0.72565, 0.7301
# train acc, test acc | 0.736433333333, 0.7413
# train acc, test acc | 0.731083333333, 0.7334
# train acc, test acc | 0.74405, 0.7489
# train acc, test acc | 0.747733333333, 0.754
# train acc, test acc | 0.7507, 0.751
# train acc, test acc | 0.74475, 0.7479
# train acc, test acc | 0.745933333333, 0.7509
# train acc, test acc | 0.7442, 0.7519
# train acc, test acc | 0.738533333333, 0.7465
# train acc, test acc | 0.736533333333, 0.7441
# train acc, test acc | 0.74665, 0.7557
# train acc, test acc | 0.7562, 0.76
# train acc, test acc | 0.758933333333, 0.7627
# train acc, test acc | 0.755516666667, 0.7611
# train acc, test acc | 0.74625, 0.7551
# train acc, test acc | 0.73915, 0.7459
# train acc, test acc | 0.722516666667, 0.7266
# train acc, test acc | 0.71205, 0.716
# train acc, test acc | 0.7095, 0.7161
# train acc, test acc | 0.71305, 0.7176
# train acc, test acc | 0.718833333333, 0.7257
# train acc, test acc | 0.725933333333, 0.7307
# train acc, test acc | 0.737316666667, 0.7435
# train acc, test acc | 0.74115, 0.7469
# train acc, test acc | 0.751266666667, 0.7576
# train acc, test acc | 0.77005, 0.7757
# train acc, test acc | 0.763016666667, 0.7684
# train acc, test acc | 0.7651, 0.7716
# train acc, test acc | 0.76385, 0.7721
# train acc, test acc | 0.767283333333, 0.7755
# train acc, test acc | 0.76145, 0.772
# train acc, test acc | 0.766333333333, 0.7708
# train acc, test acc | 0.76235, 0.7685
# train acc, test acc | 0.7671, 0.7711
# train acc, test acc | 0.780316666667, 0.783
# train acc, test acc | 0.773366666667, 0.778
# train acc, test acc | 0.763383333333, 0.7707
# train acc, test acc | 0.772366666667, 0.7783
# train acc, test acc | 0.780716666667, 0.7861
# train acc, test acc | 0.778266666667, 0.7829
# train acc, test acc | 0.767866666667, 0.7751
# train acc, test acc | 0.75625, 0.7636
# train acc, test acc | 0.758633333333, 0.7655
# train acc, test acc | 0.758216666667, 0.7658
# train acc, test acc | 0.758016666667, 0.7662
# train acc, test acc | 0.759183333333, 0.7643
# train acc, test acc | 0.75645, 0.7613
# train acc, test acc | 0.763933333333, 0.7693
# train acc, test acc | 0.76275, 0.7673
# train acc, test acc | 0.767316666667, 0.7702
# train acc, test acc | 0.7765, 0.7798
# train acc, test acc | 0.767416666667, 0.7723
# train acc, test acc | 0.764033333333, 0.7691
# train acc, test acc | 0.75315, 0.7573
# train acc, test acc | 0.758666666667, 0.764
# train acc, test acc | 0.758616666667, 0.7616
# train acc, test acc | 0.761583333333, 0.7662
# train acc, test acc | 0.760033333333, 0.7654
# train acc, test acc | 0.757766666667, 0.765
# train acc, test acc | 0.760133333333, 0.7672
# train acc, test acc | 0.758133333333, 0.7645
# train acc, test acc | 0.755233333333, 0.7632
# train acc, test acc | 0.764666666667, 0.7717
# train acc, test acc | 0.7637, 0.771
# train acc, test acc | 0.767383333333, 0.7757
# train acc, test acc | 0.767766666667, 0.7742
# train acc, test acc | 0.764033333333, 0.7713
# train acc, test acc | 0.755216666667, 0.7601
# train acc, test acc | 0.761216666667, 0.7665
# train acc, test acc | 0.767516666667, 0.7741
# train acc, test acc | 0.761316666667, 0.7692
# train acc, test acc | 0.78425, 0.7937
# train acc, test acc | 0.786216666667, 0.7948
# train acc, test acc | 0.78825, 0.7971
# train acc, test acc | 0.783833333333, 0.7925
# train acc, test acc | 0.780866666667, 0.789
# train acc, test acc | 0.7851, 0.7926
# train acc, test acc | 0.784033333333, 0.7927
# train acc, test acc | 0.785233333333, 0.7945
# train acc, test acc | 0.787183333333, 0.7948
# train acc, test acc | 0.796133333333, 0.8031
# train acc, test acc | 0.80055, 0.8049
# train acc, test acc | 0.7994, 0.8038
# train acc, test acc | 0.794633333333, 0.7992
# train acc, test acc | 0.787966666667, 0.7931
# train acc, test acc | 0.795783333333, 0.7985
# train acc, test acc | 0.784766666667, 0.7927
# train acc, test acc | 0.7853, 0.7922
# train acc, test acc | 0.7786, 0.7817
# train acc, test acc | 0.780783333333, 0.7843
# train acc, test acc | 0.785116666667, 0.7904
# train acc, test acc | 0.7854, 0.7904
# train acc, test acc | 0.775483333333, 0.7845
# train acc, test acc | 0.772966666667, 0.7836
# train acc, test acc | 0.7713, 0.782
# train acc, test acc | 0.7815, 0.7904
# train acc, test acc | 0.773966666667, 0.783
# train acc, test acc | 0.7747, 0.782
# train acc, test acc | 0.789033333333, 0.7936
# train acc, test acc | 0.79325, 0.7993
# train acc, test acc | 0.791916666667, 0.7985
# train acc, test acc | 0.790983333333, 0.7974
# train acc, test acc | 0.793483333333, 0.7983
# train acc, test acc | 0.794683333333, 0.8007
# train acc, test acc | 0.7899, 0.794
# train acc, test acc | 0.790833333333, 0.7953
# train acc, test acc | 0.792, 0.7947
# train acc, test acc | 0.797766666667, 0.7991
# train acc, test acc | 0.797816666667, 0.8
# train acc, test acc | 0.79315, 0.7956
# train acc, test acc | 0.795833333333, 0.7968
# train acc, test acc | 0.791733333333, 0.7951
# train acc, test acc | 0.79345, 0.7967
# train acc, test acc | 0.796133333333, 0.7954
# train acc, test acc | 0.799716666667, 0.7999
# train acc, test acc | 0.7972, 0.7971
# train acc, test acc | 0.799016666667, 0.802
# train acc, test acc | 0.800133333333, 0.8016
# train acc, test acc | 0.803566666667, 0.8052
# train acc, test acc | 0.804166666667, 0.8066
# train acc, test acc | 0.796716666667, 0.8002
# train acc, test acc | 0.803283333333, 0.806
# train acc, test acc | 0.80565, 0.8096
# train acc, test acc | 0.807416666667, 0.8137
# train acc, test acc | 0.808866666667, 0.8126
# train acc, test acc | 0.810466666667, 0.8144
# train acc, test acc | 0.808216666667, 0.8103
# train acc, test acc | 0.80315, 0.8073
# train acc, test acc | 0.805516666667, 0.8081
# train acc, test acc | 0.806333333333, 0.8085
# train acc, test acc | 0.807916666667, 0.8106
# train acc, test acc | 0.811583333333, 0.8146
# train acc, test acc | 0.809883333333, 0.8142
# train acc, test acc | 0.8109, 0.8159
# train acc, test acc | 0.809366666667, 0.814
# train acc, test acc | 0.8083, 0.8137
# train acc, test acc | 0.810483333333, 0.8149
# train acc, test acc | 0.810216666667, 0.8159
# train acc, test acc | 0.809616666667, 0.8155
# train acc, test acc | 0.802783333333, 0.8064
# train acc, test acc | 0.801533333333, 0.8059
# train acc, test acc | 0.802933333333, 0.8069
# train acc, test acc | 0.806933333333, 0.8102
# train acc, test acc | 0.810316666667, 0.8131
# train acc, test acc | 0.810283333333, 0.813
# train acc, test acc | 0.811083333333, 0.8154
# train acc, test acc | 0.811083333333, 0.8148
# train acc, test acc | 0.811883333333, 0.8146
# train acc, test acc | 0.810333333333, 0.8146
# train acc, test acc | 0.810366666667, 0.815
# train acc, test acc | 0.812566666667, 0.8161
# train acc, test acc | 0.812383333333, 0.8175
# train acc, test acc | 0.815416666667, 0.8202
# train acc, test acc | 0.8136, 0.8174
# train acc, test acc | 0.812733333333, 0.817
# train acc, test acc | 0.81445, 0.8186
# train acc, test acc | 0.812066666667, 0.8172
# train acc, test acc | 0.81305, 0.8184
# train acc, test acc | 0.811666666667, 0.8166
# train acc, test acc | 0.808533333333, 0.8152
# train acc, test acc | 0.810533333333, 0.8156
# train acc, test acc | 0.815133333333, 0.8181
# train acc, test acc | 0.817233333333, 0.8188
# train acc, test acc | 0.814116666667, 0.8178
# train acc, test acc | 0.81535, 0.8189
# train acc, test acc | 0.8125, 0.8174
# train acc, test acc | 0.815216666667, 0.8182
# train acc, test acc | 0.8147, 0.816
# train acc, test acc | 0.813033333333, 0.8145
# train acc, test acc | 0.812366666667, 0.8141
# train acc, test acc | 0.81605, 0.82
# train acc, test acc | 0.815533333333, 0.8184
# train acc, test acc | 0.8149, 0.8168
# train acc, test acc | 0.8194, 0.8214
# train acc, test acc | 0.816516666667, 0.8196
# train acc, test acc | 0.814816666667, 0.8201
# train acc, test acc | 0.810883333333, 0.816
# train acc, test acc | 0.81325, 0.8178
# train acc, test acc | 0.811783333333, 0.8163
# train acc, test acc | 0.819, 0.8217
# train acc, test acc | 0.819233333333, 0.8214
# train acc, test acc | 0.82205, 0.8238
# train acc, test acc | 0.81965, 0.8225
# train acc, test acc | 0.817483333333, 0.8219
# train acc, test acc | 0.814216666667, 0.8183
# train acc, test acc | 0.816633333333, 0.8202
# train acc, test acc | 0.81625, 0.8221
# train acc, test acc | 0.814733333333, 0.819
# train acc, test acc | 0.819016666667, 0.8226
# train acc, test acc | 0.818783333333, 0.8229
# train acc, test acc | 0.81705, 0.8229
# train acc, test acc | 0.812066666667, 0.8183
# train acc, test acc | 0.814483333333, 0.8202
# train acc, test acc | 0.822483333333, 0.8248
# train acc, test acc | 0.821016666667, 0.8234
# train acc, test acc | 0.823983333333, 0.8278
# train acc, test acc | 0.824716666667, 0.8287
# train acc, test acc | 0.822716666667, 0.8257
# train acc, test acc | 0.817916666667, 0.8222
# train acc, test acc | 0.815883333333, 0.8198
# train acc, test acc | 0.81265, 0.8173
# train acc, test acc | 0.815733333333, 0.8203
# train acc, test acc | 0.812766666667, 0.8158
# train acc, test acc | 0.811, 0.8166
# train acc, test acc | 0.809533333333, 0.8133
# train acc, test acc | 0.81115, 0.8164
# train acc, test acc | 0.820983333333, 0.8233
# train acc, test acc | 0.8166, 0.8215
# train acc, test acc | 0.818016666667, 0.8218
# train acc, test acc | 0.82065, 0.8248
# train acc, test acc | 0.822733333333, 0.8271
# train acc, test acc | 0.818916666667, 0.8232
# train acc, test acc | 0.82285, 0.8266
# train acc, test acc | 0.8171, 0.8217
# train acc, test acc | 0.813266666667, 0.8193
# train acc, test acc | 0.82305, 0.8273
# train acc, test acc | 0.825083333333, 0.8306
# train acc, test acc | 0.824166666667, 0.8289
# train acc, test acc | 0.820733333333, 0.8275
# train acc, test acc | 0.824183333333, 0.828
# train acc, test acc | 0.82775, 0.8317
# train acc, test acc | 0.828133333333, 0.8342
# train acc, test acc | 0.822633333333, 0.8286
# train acc, test acc | 0.819766666667, 0.8258
# train acc, test acc | 0.821916666667, 0.8279
# train acc, test acc | 0.824816666667, 0.8313
# train acc, test acc | 0.826566666667, 0.8302
# train acc, test acc | 0.827383333333, 0.8301
# train acc, test acc | 0.82745, 0.83
# train acc, test acc | 0.827366666667, 0.8304
# train acc, test acc | 0.8252, 0.8283
# train acc, test acc | 0.829866666667, 0.833
# train acc, test acc | 0.830316666667, 0.8339
# train acc, test acc | 0.828216666667, 0.8317
# train acc, test acc | 0.823766666667, 0.828
# train acc, test acc | 0.824833333333, 0.8285
# train acc, test acc | 0.822483333333, 0.8265
# train acc, test acc | 0.822283333333, 0.8247
# train acc, test acc | 0.818966666667, 0.8249
# train acc, test acc | 0.824483333333, 0.8291
# train acc, test acc | 0.825983333333, 0.8305
# train acc, test acc | 0.824033333333, 0.8291
# train acc, test acc | 0.8288, 0.8317
# train acc, test acc | 0.830166666667, 0.8345
# train acc, test acc | 0.8313, 0.8345
# train acc, test acc | 0.827216666667, 0.8301
# train acc, test acc | 0.828983333333, 0.8316
# train acc, test acc | 0.8281, 0.833
# train acc, test acc | 0.830966666667, 0.8358
# train acc, test acc | 0.82985, 0.8329
# train acc, test acc | 0.833733333333, 0.8365
# train acc, test acc | 0.834183333333, 0.8389
# train acc, test acc | 0.83415, 0.8393
# train acc, test acc | 0.834383333333, 0.8386
# train acc, test acc | 0.833116666667, 0.8385
# train acc, test acc | 0.833516666667, 0.8394
# train acc, test acc | 0.8326, 0.8374
# train acc, test acc | 0.8334, 0.8367
# train acc, test acc | 0.83105, 0.8357
# train acc, test acc | 0.83275, 0.8382
# train acc, test acc | 0.830916666667, 0.8363
# train acc, test acc | 0.832133333333, 0.8366
# train acc, test acc | 0.830266666667, 0.8344
# train acc, test acc | 0.831733333333, 0.835
# train acc, test acc | 0.832433333333, 0.8367
# train acc, test acc | 0.832766666667, 0.8368
# train acc, test acc | 0.830133333333, 0.8366
# train acc, test acc | 0.83125, 0.8358
# train acc, test acc | 0.833433333333, 0.8379
# train acc, test acc | 0.831233333333, 0.8351
# train acc, test acc | 0.831283333333, 0.8362
# train acc, test acc | 0.827833333333, 0.8337
# train acc, test acc | 0.833983333333, 0.8398
# train acc, test acc | 0.83705, 0.8441
# train acc, test acc | 0.837616666667, 0.842
# train acc, test acc | 0.839316666667, 0.8431
# train acc, test acc | 0.8385, 0.842
# train acc, test acc | 0.837833333333, 0.8436
# train acc, test acc | 0.837816666667, 0.8425
# train acc, test acc | 0.838916666667, 0.8423
# train acc, test acc | 0.840383333333, 0.8439
# train acc, test acc | 0.838583333333, 0.842
# train acc, test acc | 0.8387, 0.8416
# train acc, test acc | 0.83765, 0.8417
# train acc, test acc | 0.835866666667, 0.8386
# train acc, test acc | 0.834566666667, 0.8388
# train acc, test acc | 0.835916666667, 0.8398
# train acc, test acc | 0.8321, 0.8361
# train acc, test acc | 0.837966666667, 0.8416
# train acc, test acc | 0.838883333333, 0.8429
# train acc, test acc | 0.839733333333, 0.8436
# train acc, test acc | 0.8394, 0.8444
# train acc, test acc | 0.839483333333, 0.8427
# train acc, test acc | 0.839783333333, 0.8425
# train acc, test acc | 0.838683333333, 0.8436
# train acc, test acc | 0.837866666667, 0.8427
# train acc, test acc | 0.83935, 0.8424
# train acc, test acc | 0.840166666667, 0.8431
# train acc, test acc | 0.840383333333, 0.844
# train acc, test acc | 0.840033333333, 0.8433
# train acc, test acc | 0.840783333333, 0.8413
# train acc, test acc | 0.840383333333, 0.8433
# train acc, test acc | 0.840133333333, 0.8448
# train acc, test acc | 0.840183333333, 0.8444
# train acc, test acc | 0.8353, 0.8397
# train acc, test acc | 0.834966666667, 0.8392
# train acc, test acc | 0.833166666667, 0.8376
# train acc, test acc | 0.835133333333, 0.8393
# train acc, test acc | 0.83405, 0.84
# train acc, test acc | 0.837166666667, 0.8399
# train acc, test acc | 0.837283333333, 0.842
# train acc, test acc | 0.837816666667, 0.84
# train acc, test acc | 0.83675, 0.8396
# train acc, test acc | 0.831933333333, 0.8367
# train acc, test acc | 0.828483333333, 0.8328
# train acc, test acc | 0.82825, 0.8341
# train acc, test acc | 0.834233333333, 0.8396
# train acc, test acc | 0.834733333333, 0.8399
# train acc, test acc | 0.836016666667, 0.841
# train acc, test acc | 0.8371, 0.8438
# train acc, test acc | 0.839883333333, 0.8443
# train acc, test acc | 0.84, 0.8444
# train acc, test acc | 0.840633333333, 0.8449
# train acc, test acc | 0.842683333333, 0.8463
# train acc, test acc | 0.842133333333, 0.8468
# train acc, test acc | 0.842416666667, 0.8474
# train acc, test acc | 0.8437, 0.8482
# train acc, test acc | 0.8452, 0.8486
# train acc, test acc | 0.844816666667, 0.8465
# train acc, test acc | 0.8449, 0.8467
# train acc, test acc | 0.843183333333, 0.846
# train acc, test acc | 0.842016666667, 0.8455
# train acc, test acc | 0.842783333333, 0.8476
# train acc, test acc | 0.840733333333, 0.8447
# train acc, test acc | 0.841983333333, 0.8461
# train acc, test acc | 0.844083333333, 0.8474
# train acc, test acc | 0.844033333333, 0.8467
# train acc, test acc | 0.844316666667, 0.8464
# train acc, test acc | 0.843, 0.8453
# train acc, test acc | 0.846133333333, 0.8484
# train acc, test acc | 0.846333333333, 0.8496
# train acc, test acc | 0.846783333333, 0.8513
# train acc, test acc | 0.8464, 0.8513
# train acc, test acc | 0.84705, 0.8536
# train acc, test acc | 0.8481, 0.8513
# train acc, test acc | 0.847666666667, 0.8502
# train acc, test acc | 0.847966666667, 0.8503
# train acc, test acc | 0.84745, 0.8502
# train acc, test acc | 0.848, 0.8508
# train acc, test acc | 0.8486, 0.8517
# train acc, test acc | 0.848716666667, 0.8514
# train acc, test acc | 0.84895, 0.8518
# train acc, test acc | 0.8487, 0.8519
# train acc, test acc | 0.848883333333, 0.8532
# train acc, test acc | 0.84815, 0.8525
# train acc, test acc | 0.847866666667, 0.8516
# train acc, test acc | 0.84835, 0.8511
# train acc, test acc | 0.8465, 0.8486
# train acc, test acc | 0.84895, 0.8518
# train acc, test acc | 0.847366666667, 0.8511
# train acc, test acc | 0.8443, 0.848
# train acc, test acc | 0.84445, 0.8472
# train acc, test acc | 0.8462, 0.8498
# train acc, test acc | 0.844233333333, 0.8464
# train acc, test acc | 0.848466666667, 0.852
# train acc, test acc | 0.848, 0.8503
# train acc, test acc | 0.847683333333, 0.8514
# train acc, test acc | 0.84935, 0.8528
# train acc, test acc | 0.849533333333, 0.8524
# train acc, test acc | 0.84945, 0.8526
# train acc, test acc | 0.84695, 0.8489
# train acc, test acc | 0.849083333333, 0.8524
# train acc, test acc | 0.850916666667, 0.8552
# train acc, test acc | 0.85115, 0.8543
# train acc, test acc | 0.851366666667, 0.8542
# train acc, test acc | 0.85095, 0.8547
# train acc, test acc | 0.850633333333, 0.8553
# train acc, test acc | 0.848533333333, 0.8542
# train acc, test acc | 0.84895, 0.8521
# train acc, test acc | 0.8464, 0.8489
# train acc, test acc | 0.849116666667, 0.8532
# train acc, test acc | 0.8494, 0.8519
# train acc, test acc | 0.849516666667, 0.8536
# train acc, test acc | 0.85015, 0.8545
